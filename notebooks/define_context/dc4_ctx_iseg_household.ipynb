# %% [markdown]
# # Define Individual Segment Context &ndash; Household Use Case #
#
# ## Overview ##
#
# Explore the FEC data by specifying SQL predicates that identify **Individual Segments**, which are static lists of Individual (`indiv` table) records.  Note that Individual Segments do not distinguish between constituent Individual records that attempt to represent either the same or different real-world people.  It is up to the definer of an Individual Segment as to the meaning of the collective membership records for a segment.  Note that an Individual Segment context may including one *or more* segments (e.g. by name or ID).  As with Individual and Household contexts, Donor identities are not discernible within queries using this context type.
#
# This approach will create the following query contexts:
#
# **Principal Context View**
#
# * `ctx_iseg`
#
# **Dependent Context Views**
#
# * `ctx_iseg_memb`
# * `ctx_indiv`
# * `ctx_indiv_contrib`

# %% [markdown]
# ## Notebook Setup ##
#
# * Configure database connect information and options
# * Clear potentially interfering context (PostgreSQL doesn't let you replace a view definition with conflicting column names)
# * Set styling for notebook

# %%
sqlconnect = "postgresql+psycopg2://crash@localhost/fecdb"

# %load_ext sql
# %config SqlMagic.autopandas=True
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'
# %sql $sqlconnect
# Out:
# 'Connected: crash@fecdb'

# %% [markdown]
# Note that we drop *all* context views so we won't have any inconsistencies after this notebook is run.  After defining `ctx_indiv` below, we will define all dependent views (see Overview, above), and leave any higher-order or orthogonal views undefined

# %%
# %sql drop view if exists ctx_dseg_memb     cascade
# %sql drop view if exists ctx_dseg          cascade
# %sql drop view if exists ctx_donor_contrib cascade
# %sql drop view if exists ctx_donor         cascade
# %sql drop view if exists ctx_household     cascade
# %sql drop view if exists ctx_iseg_memb     cascade
# %sql drop view if exists ctx_iseg          cascade
# %sql drop view if exists ctx_indiv_contrib cascade
# %sql drop view if exists ctx_indiv         cascade
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%html
# <style>
#   tr, th, td {
#     text-align: left !important;
#   }
# </style>
# Out:
# <style>
#   tr, th, td {
#     text-align: left !important;
#   }
# </style>

# %% [markdown]
# ## Create Individual Segment (for Household) ##
#
# For this use case, we are defining an Individual Segment representing a household we have previously identified.
#
# Note, we are adding the "epoch" (unixtime) suffix for uniqueness, so we don't always have to clean up between runs

# %%
# %%sql result <<
# select create_indiv_seg(array_agg(i.id), concat('Sandell 9402x Household - ', round(extract(epoch from now()))))
#   from indiv i
#  where i.name like 'SANDELL, %'
#    and i.zip_code ~ '9402[58]'
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 1 rows affected.
# Returning data to local variable result

# %%
indiv_seg_id = int(result.loc[0][0])
# Out:
# 8

# %% [markdown]
# ## Create Principal View (`ctx_iseg`) ##
#
# The context will represent only the single segment, just defined.  Queries written against this context will also work for multi-segment contexts.

# %%
# %%sql
# create or replace view ctx_iseg as
# select id,
#        name,
#        description
#   from indiv_seg isg
#  where isg.id = :indiv_seg_id
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
# select *
#   from ctx_iseg
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 1 rows affected.
#    id                                  name description
# 0   8  Sandell 9402x Household - 1568437064        None

# %% [markdown]
# ## Create Dependent Views ##
#
# ### Create `ctx_iseg_memb` ###

# %%
# %%sql
# create or replace view ctx_iseg_memb as
# select ism.*
#   from ctx_iseg isx
#   join indiv_seg_memb ism on ism.indiv_seg_id = isx.id
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
# select isg.name as iseg_name,
#        i.name   as indiv_name,
#        i.city,
#        i.state,
#        i.zip_code,
#        i.elect_cycles
#   from ctx_iseg_memb ismx
#   join indiv_seg isg on isg.id = ismx.indiv_seg_id
#   join indiv i on i.id = ismx.indiv_id
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 27 rows affected.
#                                iseg_name               indiv_name  \
# 0   Sandell 9402x Household - 1568437064  SANDELL, JENNIFER A MS.
# 1   Sandell 9402x Household - 1568437064        SANDELL, JENNIFER
# 2   Sandell 9402x Household - 1568437064    SANDELL, JENNIFER MS.
# 3   Sandell 9402x Household - 1568437064      SANDELL, JENNIFER A
# 4   Sandell 9402x Household - 1568437064   SANDELL, JENNIFER AYER
# 5   Sandell 9402x Household - 1568437064        SANDELL, JENNIFER
# 6   Sandell 9402x Household - 1568437064        SANDELL, JENNIFER
# 7   Sandell 9402x Household - 1568437064        SANDELL, JENNIFER
# 8   Sandell 9402x Household - 1568437064         SANDELL, SCOTT D
# 9   Sandell 9402x Household - 1568437064      SANDELL, SCOTT MRS.
# 10  Sandell 9402x Household - 1568437064           SANDELL, SCOTT
# 11  Sandell 9402x Household - 1568437064           SANDELL, SCOTT
# 12  Sandell 9402x Household - 1568437064         SANDELL, SCOTT D
# 13  Sandell 9402x Household - 1568437064         SANDELL, SCOTT D
# 14  Sandell 9402x Household - 1568437064       SANDELL, SCOTT MR.
# 15  Sandell 9402x Household - 1568437064        SANDELL, SCOTT D.
# 16  Sandell 9402x Household - 1568437064           SANDELL, SCOTT
# 17  Sandell 9402x Household - 1568437064         SANDELL, SCOTT D
# 18  Sandell 9402x Household - 1568437064    SANDELL, SCOTT D. MR.
# 19  Sandell 9402x Household - 1568437064       SANDELL, SCOTT MR.
# 20  Sandell 9402x Household - 1568437064       SANDELL, SCOTT MR.
# 21  Sandell 9402x Household - 1568437064           SANDELL, SCOTT
# 22  Sandell 9402x Household - 1568437064         SANDELL, SCOTT D
# 23  Sandell 9402x Household - 1568437064        SANDELL, SCOTT D.
# 24  Sandell 9402x Household - 1568437064       SANDELL, SCOTT MR.
# 25  Sandell 9402x Household - 1568437064        SANDELL, SCOTT D.
# 26  Sandell 9402x Household - 1568437064       SANDELL, SCOTT MR.
#
#               city state   zip_code                    elect_cycles
# 0       MENLO PARK    CA      94025                          [2004]
# 1       MENLO PARK    CA      94025        [2004, 2006, 2008, 2010]
# 2       MENLO PARK    CA      94025                          [2004]
# 3       MENLO PARK    CA      94025                    [2006, 2008]
# 4       MENLO PARK    CA      94025                    [2004, 2010]
# 5       MENLO PARK    CA     940250                          [2004]
# 6   PORTOLA VALLEY    CA  940287608              [2016, 2018, 2020]
# 7   PORTOLA VALLEY    CA      94028                          [2018]
# 8       MENLO PARK    CA      94025        [2004, 2006, 2008, 2010]
# 9       MENLO PARK    CA      94025                          [2004]
# 10      MENLO PARK    CA  940257022              [2016, 2018, 2020]
# 11      MENLO PARK    CA      94025  [2000, 2008, 2010, 2012, 2016]
# 12      MENLO PARK    CA  940257022                          [2016]
# 13  PORTOLA VALLEY    CA  940287608                          [2016]
# 14  PORTOLA VALLEY    CA      94028                          [2018]
# 15      MENLO PARK    CA      94025                          [2010]
# 16  PORTOLA VALLEY    CA      94028                    [2010, 2016]
# 17      MENLO PARK    CA  940256112                          [2014]
# 18      MENLO PARK    CA      94025        [2000, 2008, 2010, 2012]
# 19      MENLO PARK    CA  940257022                    [2018, 2020]
# 20      MENLO PARK    CA  940256940                    [2004, 2006]
# 21  PORTOLA VALLEY    CA  940287608                          [2016]
# 22  PORTOLA VALLEY    CA      94028                          [2012]
# 23  PORTOLA VALLEY    CA      94028                          [2016]
# 24  PORTOLA VALLEY    CA  940287608                          [2018]
# 25      MENLO PARK    CA  940257022                          [2018]
# 26      MENLO PARK    CA      94025        [2000, 2002, 2004, 2006]

# %% [markdown]
# ### Create `ctx_indiv` ###

# %%
# %%sql
# create or replace view ctx_indiv as
# select i.*
#   from ctx_iseg_memb ismx
#   join indiv i on i.id = ismx.indiv_id
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
# select id,
#        name,
#        city,
#        state,
#        zip_code,
#        elect_cycles
#   from ctx_indiv
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 27 rows affected.
#           id                     name            city state   zip_code  \
# 0   10527369  SANDELL, JENNIFER A MS.      MENLO PARK    CA      94025
# 1   10527363        SANDELL, JENNIFER      MENLO PARK    CA      94025
# 2   10527371    SANDELL, JENNIFER MS.      MENLO PARK    CA      94025
# 3   10527368      SANDELL, JENNIFER A      MENLO PARK    CA      94025
# 4   10527370   SANDELL, JENNIFER AYER      MENLO PARK    CA      94025
# 5   10527364        SANDELL, JENNIFER      MENLO PARK    CA     940250
# 6   10527366        SANDELL, JENNIFER  PORTOLA VALLEY    CA  940287608
# 7   10527365        SANDELL, JENNIFER  PORTOLA VALLEY    CA      94028
# 8   10527433         SANDELL, SCOTT D      MENLO PARK    CA      94025
# 9   10527447      SANDELL, SCOTT MRS.      MENLO PARK    CA      94025
# 10  10527430           SANDELL, SCOTT      MENLO PARK    CA  940257022
# 11  10527429           SANDELL, SCOTT      MENLO PARK    CA      94025
# 12  10527435         SANDELL, SCOTT D      MENLO PARK    CA  940257022
# 13  10527437         SANDELL, SCOTT D  PORTOLA VALLEY    CA  940287608
# 14  10527445       SANDELL, SCOTT MR.  PORTOLA VALLEY    CA      94028
# 15  10527438        SANDELL, SCOTT D.      MENLO PARK    CA      94025
# 16  10527431           SANDELL, SCOTT  PORTOLA VALLEY    CA      94028
# 17  10527434         SANDELL, SCOTT D      MENLO PARK    CA  940256112
# 18  10527441    SANDELL, SCOTT D. MR.      MENLO PARK    CA      94025
# 19  10527444       SANDELL, SCOTT MR.      MENLO PARK    CA  940257022
# 20  10527443       SANDELL, SCOTT MR.      MENLO PARK    CA  940256940
# 21  10527432           SANDELL, SCOTT  PORTOLA VALLEY    CA  940287608
# 22  10527436         SANDELL, SCOTT D  PORTOLA VALLEY    CA      94028
# 23  10527440        SANDELL, SCOTT D.  PORTOLA VALLEY    CA      94028
# 24  10527446       SANDELL, SCOTT MR.  PORTOLA VALLEY    CA  940287608
# 25  10527439        SANDELL, SCOTT D.      MENLO PARK    CA  940257022
# 26  10527442       SANDELL, SCOTT MR.      MENLO PARK    CA      94025
#
#                       elect_cycles
# 0                           [2004]
# 1         [2004, 2006, 2008, 2010]
# 2                           [2004]
# 3                     [2006, 2008]
# 4                     [2004, 2010]
# 5                           [2004]
# 6               [2016, 2018, 2020]
# 7                           [2018]
# 8         [2004, 2006, 2008, 2010]
# 9                           [2004]
# 10              [2016, 2018, 2020]
# 11  [2000, 2008, 2010, 2012, 2016]
# 12                          [2016]
# 13                          [2016]
# 14                          [2018]
# 15                          [2010]
# 16                    [2010, 2016]
# 17                          [2014]
# 18        [2000, 2008, 2010, 2012]
# 19                    [2018, 2020]
# 20                    [2004, 2006]
# 21                          [2016]
# 22                          [2012]
# 23                          [2016]
# 24                          [2018]
# 25                          [2018]
# 26        [2000, 2002, 2004, 2006]

# %% [markdown]
# ### Create `ctx_indiv_contrib` ###

# %%
# %%sql
# create or replace view ctx_indiv_contrib as
# select ic.*
#   from ctx_indiv ix
#   join indiv_contrib ic on ic.indiv_id = ix.id
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
# select count(*)             as contribs,
#        sum(transaction_amt) as total_amt,
#        array_agg(distinct elect_cycle) as elect_cycles
#   from ctx_indiv_contrib
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 1 rows affected.
#    contribs  total_amt                                       elect_cycles
# 0       101  264450.00  [2000, 2002, 2004, 2006, 2008, 2010, 2012, 201...

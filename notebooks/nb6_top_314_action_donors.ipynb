# %% [markdown]
# # Query by Donor Segment #
#
# ## Overview ##
#
# This approach will create the following query contexts:
#
# * `ctx_dseg`
# * `ctx_dseg_memb`
# * `ctx_donor`
# * `ctx_indiv`
# * `ctx_contrib`

# %% [markdown]
# ## Notebook Setup ##
#
# * Configure database connect information and options
# * Clear potentially interfering context (PostgreSQL doesn't let you replace a view definition with conflicting column names)
# * Set styling for notebook

# %%
sqlconnect = "postgresql+psycopg2://crash@localhost/fecdb"

# %load_ext sql
# %config SqlMagic.autopandas=True
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'
# %sql $sqlconnect
# Out:
# 'Connected: crash@fecdb'

# %%
# %sql drop view if exists ctx_contrib cascade
# %sql drop view if exists ctx_indiv cascade
# %sql drop view if exists ctx_donor cascade
# %sql drop view if exists ctx_dseg_memb cascade
# %sql drop view if exists ctx_dseg cascade
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%html
# <style>
#   tr, th, td {
#     text-align: left !important;
#   }
# </style>
# Out:
# <style>
#   tr, th, td {
#     text-align: left !important;
#   }
# </style>

# %% [markdown]
# ## Create Donor Segment for Top 314 Donors ##

# %%
# %sql delete from donor_seg
# %sql drop table if exists seg_def
# %sql drop materialized view if exists donor_sum
# %sql drop materialized view if exists donor_sum_314
# %sql drop materialized view if exists indiv_group
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 15 rows affected.
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
# create materialized view indiv_group as
# select ip.part1                  as last_name,
#        substr(ip.part2, 1, 3)    as first_name_pfx,
#        substr(ip.zip_code, 1, 3) as zip_pfx,
#        count(distinct ip.id)     as indivs,
#        array_agg(distinct ip.id) as indiv_ids
#   from indiv_parsed ip
#  where ip.name ~ '^[A-Z][^,]'
#    and ip.zip_code is not null
#    and ip.num_parts > 1
#    and ip.part1 !~ ' '
#  group by 1, 2, 3
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 6738578 rows affected.
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Create a view to represent `indiv_contrib` records associated with any committee whose name is prefixed by "314" (this can be amended if there are other patterns representing the same PAC; currently there are no others with "314" elsewhere in the name)
#
# Note that this serves as a template for creating other segments of contributions, and hence the donors (actually, just "individuals" for now) behind them, for doing a similar type of investigation

# %%
# %%sql
# create or replace view contrib_to_314 as
# select cm.cmte_nm,
#        ic.*
#   from cmte cm
#   join indiv_contrib ic
#        on ic.cmte_id = cm.cmte_id
#  where cm.cmte_nm like '314%'
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Not sure whether it is better to re-aggregate the unnested ids (even though we are not able to omit the `distinct` qualifier), or select `ig.indiv_ids` and add to GROUP BY clause&mdash;voting for the former option right now...

# %%
# %%sql
# create materialized view donor_sum_314 as
# with indiv_group_memb as (
#     select ig.last_name,
#            ig.first_name_pfx,
#            ig.zip_pfx,
#            --ig.indiv_ids,
#            unnest(ig.indiv_ids) as indiv_id
#       from indiv_group ig
# )
# select igm.last_name,
#        igm.first_name_pfx,
#        igm.zip_pfx,
#        array_agg(distinct igm.indiv_id)
#                                  as indiv_ids,
#        count(ct.transaction_amt) as contribs,
#        sum(ct.transaction_amt)   as total_amt,
#        round(sum(ct.transaction_amt) / count(ct.transaction_amt), 2)
#                                  as avg_amt,
#        array_agg(distinct ct.elect_cycle)
#                                  as elect_cycles
#   from indiv_group_memb igm
#   join contrib_to_314 ct on ct.indiv_id = igm.indiv_id
#  group by 1, 2, 3
#  order by 6 desc, 5 desc
#  limit 50
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 50 rows affected.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
# select *
#   from donor_sum_314
#  order by total_amt desc, contribs desc
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 50 rows affected.
#      last_name first_name_pfx zip_pfx                    indiv_ids  contribs  \
# 0       STOREY            BAY     191                   [11659801]        21
# 1       ROSZAK            MAT     600                   [10325529]         2
# 2      PROCKOP            DAR     191                    [9683572]         2
# 3         PARK            TOD     940                    [9188602]         2
# 4      SHENKER            SCO     947                   [10979072]         7
# 5      GIRARDI            THO     900                    [4336953]         4
# 6         NASH            RIC     598                    [8656333]         2
# 7     ABRAMSON            RON     200                      [28429]         4
# 8       TAYLOR            DAL     606                   [11902785]         2
# 9       LARSEN            CHR     941                    [6822374]         2
# 10      MORGAN            HOW     100                    [8417423]         2
# 11     SOLIMAN            KAR     926                   [11356137]         2
# 12      MCEVOY            NIO     941                    [7863787]        42
# 13        KAHN            RON     941           [6110433, 6110440]        13
# 14        PARK            DAV     940                    [9165471]         4
# 15      TORRES            TOM     770                   [12143213]        36
# 16  NEGROPONTE            NIC     021                    [8688914]         2
# 17       BASSI            STE     920                     [678448]         2
# 18  GROSSBLATT            DAV     941                    [4684620]         2
# 19     CUELLAR            CLI     984                    [2576925]        12
# 20    LAWRENCE            FRA     640                    [6872845]         6
# 21    SWINDELL            DAV     021                   [11823232]         4
# 22      PROOPS            JAY     598                    [9688035]         2
# 23       GURAL            JEF     100                    [4745356]         2
# 24       SHOCH            JOH     940                   [11024692]         2
# 25    HONARKAR            MOH     926                    [5486301]         2
# 26       BYERS            BRO     940                    [1661575]         2
# 27      HUDSON            BRU     132                    [5601495]         6
# 28       JHONG            EUG     940                    [5902719]         2
# 29     KARPLUS            BAR     913                    [6169689]         4
# 30      GOLLON            PET     117                    [4435025]        18
# 31      NORTON            JAC     100  [8848719, 8848720, 8848731]        18
# 32     GILBERT            JOH     024                    [4293837]        90
# 33       KAPER            TAS     019                    [6147085]        10
# 34    LEVINSON            FRA     949                    [7037936]         3
# 35    BEEUWKES            REI     017                     [779629]         3
# 36        KIRK            CLA     100           [6433238, 6433258]         8
# 37      JENCKS            CHR     021                    [5870457]        42
# 38     FERSTER            DAV     600                    [3678807]         6
# 39     NIELSEN            SHE     600                    [8793106]        60
# 40     HORLICK            SUS     323                    [5515167]        60
# 41        TUSK            BRA     100                   [12265351]         2
# 42       FORDE            JAM     927                    [3850042]         2
# 43        BERG            FRE     045                     [877907]         6
# 44       MOUNT            PHY     064                    [8496236]        10
# 45      POWERS            ANN     960                    [9625220]        10
# 46        HALL            CLA     145                    [4828088]         4
# 47        BLUE            ALL     902                    [1083690]         2
# 48    FRIEDMAN            DON     294                    [3993057]         2
# 49    FRIEDMAN            RAN     294                    [3997846]         2
#
#     total_amt    avg_amt              elect_cycles
# 0   240000.00   11428.57                    [2016]
# 1   204562.00  102281.00                    [2018]
# 2   200000.00  100000.00                    [2018]
# 3   200000.00  100000.00                    [2018]
# 4   105500.00   15071.43              [2014, 2018]
# 5   100000.00   25000.00                    [2018]
# 6   100000.00   50000.00                    [2018]
# 7    50000.00   12500.00                    [2018]
# 8    50000.00   25000.00                    [2018]
# 9    50000.00   25000.00                    [2018]
# 10   50000.00   25000.00                    [2018]
# 11   49890.00   24945.00                    [2018]
# 12   42966.00    1023.00                    [2016]
# 13   42000.00    3230.77              [2016, 2018]
# 14   40312.00   10078.00                    [2018]
# 15   36000.00    1000.00              [2014, 2016]
# 16   22378.00   11189.00                    [2018]
# 17   20466.00   10233.00                    [2018]
# 18   20230.00   10115.00                    [2018]
# 19   20050.00    1670.83                    [2020]
# 20   20010.00    3335.00                    [2020]
# 21   20000.00    5000.00                    [2018]
# 22   20000.00   10000.00                    [2018]
# 23   20000.00   10000.00                    [2018]
# 24   20000.00   10000.00                    [2018]
# 25   20000.00   10000.00                    [2018]
# 26   20000.00   10000.00                    [2018]
# 27   18000.00    3000.00                    [2016]
# 28   16604.00    8302.00                    [2018]
# 29   16000.00    4000.00                    [2020]
# 30   15900.00     883.33              [2018, 2020]
# 31   15700.00     872.22  [2014, 2016, 2018, 2020]
# 32   15450.00     171.67              [2018, 2020]
# 33   15000.00    1500.00                    [2018]
# 34   15000.00    5000.00                    [2016]
# 35   15000.00    5000.00                    [2016]
# 36   14500.00    1812.50        [2016, 2018, 2020]
# 37   14320.00     340.95              [2016, 2018]
# 38   13500.00    2250.00                    [2018]
# 39   13238.00     220.63              [2018, 2020]
# 40   11716.00     195.27              [2018, 2020]
# 41   10800.00    5400.00                    [2018]
# 42   10800.00    5400.00                    [2018]
# 43   10260.00    1710.00                    [2018]
# 44   10092.00    1009.20              [2018, 2020]
# 45   10000.00    1000.00                    [2018]
# 46   10000.00    2500.00                    [2018]
# 47   10000.00    5000.00                    [2018]
# 48   10000.00    5000.00                    [2018]
# 49   10000.00    5000.00                    [2018]

# %%
# %%sql
# with donor_set as (
#     select row(indiv_ids)::id_array as ids
#       from donor_sum_314
# )
# select create_donor_seg(array_agg(ids), 'Top 314 Donors')
#   from donor_set
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 1 rows affected.
#    create_donor_seg
# 0                64

# %% [markdown]
# ## Create Context Views ##
#
# ### Create `ctx_dseg` ###

# %%
# %%sql
# create or replace view ctx_dseg as
# select id,
#        name,
#        description
#   from donor_seg ds
#  where ds.name = 'Top 314 Donors'
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
# select *
#   from ctx_dseg
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 1 rows affected.
#    id            name description
# 0  64  Top 314 Donors        None

# %%
# %%sql
# with seg_donors as (
#     select dsm.donor_indiv_id
#       from ctx_dseg dsx
#       join donor_seg_memb dsm on dsm.donor_seg_id = dsx.id
# )
# select i.id,
#        i.name,
#        i.city,
#        i.state,
#        i.zip_code
#   from seg_donors sd
#   join indiv i on i.id = sd.donor_indiv_id
#  order by i.name, i.zip_code
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 50 rows affected.
# 44  11356137               SOLIMAN, KARL           IRVINE    CA  926127186
# 45  11659801      STOREY, BAYARD T PH.D.     PHILADELPHIA    PA  191303202
# 46  11823232              SWINDELL, DAVE           BOSTON    MA  021163510
# 47  11902785                TAYLOR, DALE          CHICAGO    IL  606146085
# 48  12143213               TORRES, TOMAS          HOUSTON    TX  770653124
# 49  12265351               TUSK, BRADLEY         NEW YORK    NY  100039605

# %% [markdown]
# ### Create `ctx_dseg_memb` ###

# %%
# %%sql
# create or replace view ctx_dseg_memb as
# select dsm.*
#   from ctx_dseg dsx
#   join donor_seg_memb dsm on dsm.donor_seg_id = dsx.id
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
# select ds.name as dseg_name,
#        d.name  as indiv_name,
#        d.city,
#        d.state,
#        d.zip_code,
#        d.elect_cycles
#   from ctx_dseg_memb dsmx
#   join donor_seg ds on ds.id = dsmx.donor_seg_id
#   join donor_indiv d on d.id = dsmx.donor_indiv_id
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 50 rows affected.
#          dseg_name                  indiv_name             city state  \
# 0   Top 314 Donors      STOREY, BAYARD T PH.D.     PHILADELPHIA    PA
# 1   Top 314 Donors             ROSZAK, MATTHEW         WINNETKA    IL
# 2   Top 314 Donors  PROCKOP, DARWIN J. MD, PHD     PHILADELPHIA    PA
# 3   Top 314 Donors                  PARK, TODD  LOS ALTOS HILLS    CA
# 4   Top 314 Donors              SHENKER, SCOTT         BERKELEY    CA
# 5   Top 314 Donors          GIRARDI, THOMAS V.      LOS ANGELES    CA
# 6   Top 314 Donors               NASH, RICHARD         MISSOULA    MT
# 7   Top 314 Donors            ABRAMSON, RONALD       WASHINGTON    DC
# 8   Top 314 Donors                TAYLOR, DALE          CHICAGO    IL
# 9   Top 314 Donors               LARSEN, CHRIS    SAN FRANCISCO    CA
# 10  Top 314 Donors           MORGAN, HOWARD L.         NEW YORK    NY
# 11  Top 314 Donors               SOLIMAN, KARL           IRVINE    CA
# 12  Top 314 Donors                MCEVOY, NION    SAN FRANCISCO    CA
# 13  Top 314 Donors              KAHN, RONALD N    SAN FRANCISCO    CA
# 14  Top 314 Donors                 PARK, DAVID        LOS ALTOS    CA
# 15  Top 314 Donors               TORRES, TOMAS          HOUSTON    TX
# 16  Top 314 Donors        NEGROPONTE, NICHOLAS        CAMBRIDGE    MA
# 17  Top 314 Donors                BASSI, STEVE         CARLSBAD    CA
# 18  Top 314 Donors           GROSSBLATT, DAVID    SAN FRANCISCO    CA
# 19  Top 314 Donors           CUELLAR, CLIFFORD           TACOMA    WA
# 20  Top 314 Donors             LAWRENCE, FRANK      LEES SUMMIT    MO
# 21  Top 314 Donors              SWINDELL, DAVE           BOSTON    MA
# 22  Top 314 Donors                 PROOPS, JAY           OVANDO    MT
# 23  Top 314 Donors              GURAL, JEFFREY         NEW YORK    NY
# 24  Top 314 Donors             SHOCH, JOHN PHD         WOODSIDE    CA
# 25  Top 314 Donors          HONARKAR, MOHAMMAD           IRVINE    CA
# 26  Top 314 Donors                BYERS, BROOK       MENLO PARK    CA
2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020]
# 36  100215251                           [2014, 2016, 2018, 2020]
# 37  021382409         [2004, 2006, 2012, 2014, 2016, 2018, 2020]
# 38  600911553                           [2014, 2016, 2018, 2020]
# 39  600932015                           [2014, 2016, 2018, 2020]
# 40  323117834                                 [2016, 2018, 2020]
# 41  100039605                           [2014, 2016, 2018, 2020]
# 42  927806320                                             [2018]
# 43  045633307                                       [2016, 2018]
# 44  064885719                                       [2018, 2020]
# 45  960252504                                       [2016, 2018]
# 46  145641102                                             [2018]
# 47  902913830                                       [2016, 2018]
# 48  294644305                           [2014, 2016, 2018, 2020]
# 49  294644305                                       [2018, 2020]

# %% [markdown]
# ### Create `ctx_donor` ###

# %%
# %%sql
# create or replace view ctx_donor as
# select d.*
#   from ctx_dseg_memb dsmx
#   join donor_indiv d on d.id = dsmx.donor_indiv_id
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
# select id,
#        name,
#        city,
#        state,
#        zip_code,
#        elect_cycles
#   from ctx_donor
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 50 rows affected.
#           id                        name             city state   zip_code  \
# 0   11659801      STOREY, BAYARD T PH.D.     PHILADELPHIA    PA  191303202
# 1   10325529             ROSZAK, MATTHEW         WINNETKA    IL  600933630
# 2    9683572  PROCKOP, DARWIN J. MD, PHD     PHILADELPHIA    PA  191063913
# 3    9188602                  PARK, TODD  LOS ALTOS HILLS    CA  940223385
# 4   10979072              SHENKER, SCOTT         BERKELEY    CA  947072052
# 5    4336953          GIRARDI, THOMAS V.      LOS ANGELES    CA  900171904
# 6    8656333               NASH, RICHARD         MISSOULA    MT  598045862
# 7      28429            ABRAMSON, RONALD       WASHINGTON    DC  200063807
# 8   11902785                TAYLOR, DALE          CHICAGO    IL  606146085
# 9    6822374               LARSEN, CHRIS    SAN FRANCISCO    CA  941091512
# 10   8417423           MORGAN, HOWARD L.         NEW YORK    NY  100657253
# 11  11356137               SOLIMAN, KARL           IRVINE    CA  926127186
# 12   7863787                MCEVOY, NION    SAN FRANCISCO    CA      94118
# 13   6110433              KAHN, RONALD N    SAN FRANCISCO    CA  941590599
# 14   9165471                 PARK, DAVID        LOS ALTOS    CA  940223838
# 15  12143213               TORRES, TOMAS          HOUSTON    TX  770653124
# 16   8688914        NEGROPONTE, NICHOLAS        CAMBRIDGE    MA  021421322
# 17    678448                BASSI, STEVE         CARLSBAD    CA  920081900
# 18   4684620           GROSSBLATT, DAVID    SAN FRANCISCO    CA  941074317
# 19   2576925           CUELLAR, CLIFFORD           TACOMA    WA  984053360
# 20   6872845             LAWRENCE, FRANK      LEES SUMMIT    MO  640863079
# 21  11823232              SWINDELL, DAVE           BOSTON    MA  021163510
# 22   9688035                 PROOPS, JAY           OVANDO    MT  598540149
# 23   4745356              GURAL, JEFFREY         NEW YORK    NY  100175529
# 24  11024692             SHOCH, JOHN PHD         WOODSIDE    CA  940622538
# 25   5486301          HONARKAR, MOHAMMAD           IRVINE    CA  926184236
# 26   1661575                BYERS, BROOK       MENLO PARK    CA  940257020
# 27   5601495            HUDSON, BRUCE S.         SYRACUSE    NY  132103116
# 28   5902719               JHONG, EUGENE        LOS ALTOS    CA  940221702
# 29   6169689            KARPLUS, BARBARA     NEWBURY PARK    CA  913202803
# 30   4435025               GOLLON, PETER       HUNTINGTON    NY  117431918
# 31   8848719                NORTON, JACK         NEW YORK    NY      10027
# 32   4293837               GILBERT, JOHN        BROOKLINE    MA  024465769
# 33   6147085                KAPER, TASSO       MANCHESTER    MA  019441048
# 34   7037936             LEVINSON, FRANK          TIBURON    CA  949202523
# 35    779629           BEEUWKES, REINIER          CONCORD    MA  017425322
# 36   6433238                  KIRK, CLAY         NEW YORK    NY  100215251
# 37   5870457         JENCKS, CHRISTOPHER        CAMBRIDGE    MA  021382409
# 38   3678807              FERSTER, DAVID         WILMETTE    IL  600911553
# 39   8793106             NIELSEN, SHEILA         WINNETKA    IL  600932015
# 40   5515167              HORLICK, SUSAN      TALLAHASSEE    FL  323117834
# 41  12265351               TUSK, BRADLEY         NEW YORK    NY  100039605
# 42   3850042                FORDE, JAMES           TUSTIN    CA  927806320
# 43    877907                  BERG, FRED          CUSHING    ME  045633307
# 44   8496236           MOUNT, PHYLLIS F.        SOUTHBURY    CT  064885719
# 45   9625220                 POWERS, ANN         DUNSMUIR    CA  960252504
# 46   4828088                HALL, CLAIRE           VICTOR    NY  145641102
# 47   1083690                 BLUE, ALLEN           VENICE    CA  902913830
# 48   3993057             FRIEDMAN, DONNA   MOUNT PLEASANT    SC  294644305
# 49   3997846          FRIEDMAN, RANDOLPH   MOUNT PLEASANT    SC  294644305
#
#                                          elect_cycles
# 0                                  [2006, 2014, 2016]
# 1                                        [2018, 2020]
# 2                                        [2016, 2018]
# 3                                        [2018, 2020]
# 4                            [2014, 2016, 2018, 2020]
# 5                            [2014, 2016, 2018, 2020]
# 6                                              [2018]
# 7                      [2012, 2014, 2016, 2018, 2020]
# 8                                  [2016, 2018, 2020]
# 9                            [2010, 2016, 2018, 2020]
# 10                                             [2018]
# 11                                             [2018]
# 12  [2002, 2004, 2006, 2008, 2010, 2012, 2014, 201...
# 13                           [2014, 2016, 2018, 2020]
# 14                                             [2018]
# 15                     [2012, 2014, 2016, 2018, 2020]
# 16                                             [2018]
# 17                                             [2018]
# 18                                             [2018]
# 19                                 [2016, 2018, 2020]
# 20                                       [2016, 2020]
# 21                                             [2018]
# 22                                             [2018]
# 23                     [2004, 2014, 2016, 2018, 2020]
# 24                                       [2016, 2018]
# 25                                       [2016, 2018]
# 26                           [2014, 2016, 2018, 2020]
# 27                                             [2016]
# 28                                       [2018, 2020]
# 29                                 [2016, 2018, 2020]
# 30                           [2014, 2016, 2018, 2020]
# 31                     [2010, 2012, 2014, 2016, 2018]
# 32               [2004, 2006, 2014, 2016, 2018, 2020]
# 33                           [2014, 2016, 2018, 2020]
# 34                                 [2016, 2018, 2020]
# 35   [2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020]
# 36                           [2014, 2016, 2018, 2020]
# 37         [2004, 2006, 2012, 2014, 2016, 2018, 2020]
# 38                           [2014, 2016, 2018, 2020]
# 39                           [2014, 2016, 2018, 2020]
# 40                                 [2016, 2018, 2020]
# 41                           [2014, 2016, 2018, 2020]
# 42                                             [2018]
# 43                                       [2016, 2018]
# 44                                       [2018, 2020]
# 45                                       [2016, 2018]
# 46                                             [2018]
# 47                                       [2016, 2018]
# 48                           [2014, 2016, 2018, 2020]
# 49                                       [2018, 2020]

# %% [markdown]
# ### Create `ctx_indiv` ###

# %%
# %%sql
# create or replace view ctx_indiv as
# select i.*
#   from ctx_donor dx
#   join indiv i on i.donor_indiv_id = dx.id
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
# select id,
#        name,
#        city,
#        state,
#        zip_code,
#        elect_cycles,
#        donor_indiv_id
#   from ctx_indiv
#  order by donor_indiv_id, name
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 54 rows affected.
#           id                        name             city state   zip_code  \
# 0      28429            ABRAMSON, RONALD       WASHINGTON    DC  200063807
# 1     678448                BASSI, STEVE         CARLSBAD    CA  920081900
# 2     779629           BEEUWKES, REINIER          CONCORD    MA  017425322
# 3     877907                  BERG, FRED          CUSHING    ME  045633307
# 4    1083690                 BLUE, ALLEN           VENICE    CA  902913830
# 5    1661575                BYERS, BROOK       MENLO PARK    CA  940257020
# 6    2576925           CUELLAR, CLIFFORD           TACOMA    WA  984053360
# 7    3678807              FERSTER, DAVID         WILMETTE    IL  600911553
# 8    3850042                FORDE, JAMES           TUSTIN    CA  927806320
# 9    3993057             FRIEDMAN, DONNA   MOUNT PLEASANT    SC  294644305
# 10   3997846          FRIEDMAN, RANDOLPH   MOUNT PLEASANT    SC  294644305
# 11   4293837               GILBERT, JOHN        BROOKLINE    MA  024465769
# 12   4336953          GIRARDI, THOMAS V.      LOS ANGELES    CA  900171904
# 13   4435025               GOLLON, PETER       HUNTINGTON    NY  117431918
# 14   4684620           GROSSBLATT, DAVID    SAN FRANCISCO    CA  941074317
# 15   4745356              GURAL, JEFFREY         NEW YORK    NY  100175529
# 16   4828088                HALL, CLAIRE           VICTOR    NY  145641102
# 17   5486301          HONARKAR, MOHAMMAD           IRVINE    CA  926184236
# 18   5515167              HORLICK, SUSAN      TALLAHASSEE    FL  323117834
# 19   5601495            HUDSON, BRUCE S.         SYRACUSE    NY  132103116
# 20   5870457         JENCKS, CHRISTOPHER        CAMBRIDGE    MA  021382409
# 21   5902719               JHONG, EUGENE        LOS ALTOS    CA  940221702
# 22   6110433              KAHN, RONALD N    SAN FRANCISCO    CA  941590599
# 23   6110440             KAHN, RONALD N.    SAN FRANCISCO    CA  941590599
# 24   6147085                KAPER, TASSO       MANCHESTER    MA  019441048
# 25   6169689            KARPLUS, BARBARA     NEWBURY PARK    CA  913202803
# 26   6433238                  KIRK, CLAY         NEW YORK    NY  100215251
# 27   6433258            KIRK, CLAY KENAN         NEW YORK    NY  100215251
# 28   6822374               LARSEN, CHRIS    SAN FRANCISCO    CA  941091512
[2002, 2004, 2006, 2008, 2010, 2012, 2014, 201...         7863787
# 32                                             [2018]         8417423
# 33                                       [2018, 2020]         8496236
# 34                                             [2018]         8656333
# 35                                             [2018]         8688914
# 36                           [2014, 2016, 2018, 2020]         8793106
# 37                     [2010, 2012, 2014, 2016, 2018]         8848719
# 38                           [2014, 2016, 2018, 2020]         8848719
# 39                                       [2012, 2018]         8848719
# 40                                             [2018]         9165471
# 41                                       [2018, 2020]         9188602
# 42                                       [2016, 2018]         9625220
# 43                                       [2016, 2018]         9683572
# 44                                             [2018]         9688035
# 45                                       [2018, 2020]        10325529
# 46                           [2014, 2016, 2018, 2020]        10979072
# 47                                       [2016, 2018]        11024692
# 48                                             [2018]        11356137
# 49                                 [2006, 2014, 2016]        11659801
# 50                                             [2018]        11823232
# 51                                 [2016, 2018, 2020]        11902785
# 52                     [2012, 2014, 2016, 2018, 2020]        12143213
# 53                           [2014, 2016, 2018, 2020]        12265351

# %% [markdown]
# ### Create `ctx_contrib` ###

# %%
# %%sql
# create or replace view ctx_contrib as
# select ic.*,
#        ix.donor_indiv_id
#   from ctx_indiv ix
#   join indiv_contrib ic on ic.indiv_id = ix.id
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
# select count(*)             as contribs,
#        sum(transaction_amt) as total_amt,
#        array_agg(distinct elect_cycle) as elect_cycles
#   from ctx_contrib
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 1 rows affected.
#    contribs   total_amt                                       elect_cycles
# 0      4369  6663529.00  [2002, 2004, 2006, 2008, 2010, 2012, 2014, 201...

# %% [markdown]
# ## Query Based on Context ##
#
# ### Query using `ctx_dseg` ###

# %%
# %%sql
# select ic.elect_cycle,
#        count(*) cycle_contribs,
#        sum(ic.transaction_amt) cycle_amount,
#        round(avg(ic.transaction_amt), 2) avg_amount,
#        min(ic.transaction_amt) min_amount,
#        max(ic.transaction_amt) max_amount
#   from ctx_dseg dsx
#   join donor_seg_memb dsm on dsm.donor_seg_id = dsx.id
#   join indiv i on i.donor_indiv_id = dsm.donor_indiv_id
#   join indiv_contrib ic on ic.indiv_id = i.id
#  group by 1
#  order by 1
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 10 rows affected.
#    elect_cycle  cycle_contribs cycle_amount avg_amount min_amount max_amount
# 0         2002               5      3500.00     700.00     250.00    1000.00
# 1         2004               8     31000.00    3875.00     500.00   25000.00
# 2         2006              17     14200.00     835.29     200.00    2000.00
# 3         2008              22     13100.00     595.45     200.00    2300.00
# 4         2010              18     12250.00     680.56     250.00    2500.00
# 5         2012              19     21000.00    1105.26     250.00   10000.00
# 6         2014             322    635002.00    1972.06   -2600.00  100000.00
# 7         2016            1066   1493514.00    1401.05   -2700.00   73175.00
# 8         2018            2563   3892299.00    1518.65   -2744.00  102281.00
# 9         2020             329    547664.00    1664.63   -2800.00   50000.00

# %% [markdown]
# ### Query using `ctx_dseg_memb` ###

# %%
# %%sql
# select ic.elect_cycle,
#        count(*) cycle_contribs,
#        sum(ic.transaction_amt) cycle_amount,
#        round(avg(ic.transaction_amt), 2) avg_amount,
#        min(ic.transaction_amt) min_amount,
#        max(ic.transaction_amt) max_amount
#   from ctx_dseg_memb dsmx
#   join indiv i on i.donor_indiv_id = dsmx.donor_indiv_id
#   join indiv_contrib ic on ic.indiv_id = i.id
#  group by 1
#  order by 1
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 10 rows affected.
#    elect_cycle  cycle_contribs cycle_amount avg_amount min_amount max_amount
# 0         2002               5      3500.00     700.00     250.00    1000.00
# 1         2004               8     31000.00    3875.00     500.00   25000.00
# 2         2006              17     14200.00     835.29     200.00    2000.00
# 3         2008              22     13100.00     595.45     200.00    2300.00
# 4         2010              18     12250.00     680.56     250.00    2500.00
# 5         2012              19     21000.00    1105.26     250.00   10000.00
# 6         2014             322    635002.00    1972.06   -2600.00  100000.00
# 7         2016            1066   1493514.00    1401.05   -2700.00   73175.00
# 8         2018            2563   3892299.00    1518.65   -2744.00  102281.00
# 9         2020             329    547664.00    1664.63   -2800.00   50000.00

# %% [markdown]
# ### Query using `ctx_indiv` ###

# %%
# %%sql
# select ic.elect_cycle,
#        count(*) cycle_contribs,
#        sum(ic.transaction_amt) cycle_amount,
#        round(avg(ic.transaction_amt), 2) avg_amount,
#        min(ic.transaction_amt) min_amount,
#        max(ic.transaction_amt) max_amount
#   from ctx_indiv ix
#   join indiv_contrib ic on ic.indiv_id = ix.id
#  group by 1
#  order by 1
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 10 rows affected.
#    elect_cycle  cycle_contribs cycle_amount avg_amount min_amount max_amount
# 0         2002               5      3500.00     700.00     250.00    1000.00
# 1         2004               8     31000.00    3875.00     500.00   25000.00
# 2         2006              17     14200.00     835.29     200.00    2000.00
# 3         2008              22     13100.00     595.45     200.00    2300.00
# 4         2010              18     12250.00     680.56     250.00    2500.00
# 5         2012              19     21000.00    1105.26     250.00   10000.00
# 6         2014             322    635002.00    1972.06   -2600.00  100000.00
# 7         2016            1066   1493514.00    1401.05   -2700.00   73175.00
# 8         2018            2563   3892299.00    1518.65   -2744.00  102281.00
# 9         2020             329    547664.00    1664.63   -2800.00   50000.00

# %% [markdown]
# ### Query using `ctx_contrib` ###

# %%
# %%sql
# select cx.elect_cycle,
#        count(*) cycle_contribs,
#        sum(cx.transaction_amt) cycle_amount,
#        round(avg(cx.transaction_amt), 2) avg_amount,
#        min(cx.transaction_amt) min_amount,
#        max(cx.transaction_amt) max_amount
#   from ctx_contrib cx
#  group by 1
#  order by 1
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 10 rows affected.
#    elect_cycle  cycle_contribs cycle_amount avg_amount min_amount max_amount
# 0         2002               5      3500.00     700.00     250.00    1000.00
# 1         2004               8     31000.00    3875.00     500.00   25000.00
# 2         2006              17     14200.00     835.29     200.00    2000.00
# 3         2008              22     13100.00     595.45     200.00    2300.00
# 4         2010              18     12250.00     680.56     250.00    2500.00
# 5         2012              19     21000.00    1105.26     250.00   10000.00
# 6         2014             322    635002.00    1972.06   -2600.00  100000.00
# 7         2016            1066   1493514.00    1401.05   -2700.00   73175.00
# 8         2018            2563   3892299.00    1518.65   -2744.00  102281.00
# 9         2020             329    547664.00    1664.63   -2800.00   50000.00

# %%
# %%sql
# select d.id as donor_id,
#        d.name as donor_name,
#        count(*) contribs,
#        sum(cx.transaction_amt) total_amount,
#        round(avg(cx.transaction_amt), 2) avg_amount,
#        min(cx.transaction_amt) min_amount,
#        max(cx.transaction_amt) max_amount,
#        array_agg(distinct cx.elect_cycle) elect_cycles
#   from ctx_contrib cx
#   join donor_indiv d on d.id = cx.donor_indiv_id
#  group by 1, 2
#  order by 4 desc
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 50 rows affected.
#     donor_id                  donor_name  contribs total_amount avg_amount  \
# 0     779629           BEEUWKES, REINIER       433    888258.00    2051.40
# 1    6169689            KARPLUS, BARBARA       340    878285.00    2583.19
# 2   10979072              SHENKER, SCOTT       241    849800.00    3526.14
# 3      28429            ABRAMSON, RONALD       295    471583.00    1598.59
# 4    1083690                 BLUE, ALLEN        81    426400.00    5264.20
# 5    7863787                MCEVOY, NION       558    383899.00     687.99
# 6   11902785                TAYLOR, DALE        48    258050.00    5376.04
# 7    4336953          GIRARDI, THOMAS V.        24    235100.00    9795.83
# 8    6433238                  KIRK, CLAY        98    211850.00    2161.73
# 9    1661575                BYERS, BROOK        60    194900.00    3248.33
# 10   9188602                  PARK, TODD        26    155414.00    5977.46
# 11   4745356              GURAL, JEFFREY        49    134500.00    2744.90
# 12   6822374               LARSEN, CHRIS        26    115200.00    4430.77
# 13   8793106             NIELSEN, SHEILA       474    113619.00     239.70
# 14  10325529             ROSZAK, MATTHEW         6    110181.00   18363.50
# 15   6110433              KAHN, RONALD N        38    105600.00    2778.95
# 16   8848719                NORTON, JACK       200    102475.00     512.38
# 17   5870457         JENCKS, CHRISTOPHER       309    102033.00     330.20
# 18   9683572  PROCKOP, DARWIN J. MD, PHD         3    102000.00   34000.00
# 19  11659801      STOREY, BAYARD T PH.D.        16     91700.00    5731.25
# 20   4435025               GOLLON, PETER       169     87000.00     514.79
# 21   3993057             FRIEDMAN, DONNA        22     58550.00    2661.36
# 22   8656333               NASH, RICHARD         5     58099.00   11619.80
# 23  12143213               TORRES, TOMAS       128     58062.00     453.61
# 24  12265351               TUSK, BRADLEY        21     55600.00    2647.62
# 25   4293837               GILBERT, JOHN        94     39225.00     417.29
# 26   9165471                 PARK, DAVID        12     36345.00    3028.75
# 27   3678807              FERSTER, DAVID        62     32058.00     517.06
# 28   7037936             LEVINSON, FRANK        43     31541.00     733.51
# 29   6147085                KAPER, TASSO        65     25109.00     386.29
# 30  11356137               SOLIMAN, KARL         9     25033.00    2781.44
# 31   8417423           MORGAN, HOWARD L.         1     25000.00   25000.00
# 32   8688914        NEGROPONTE, NICHOLAS         7     21987.00    3141.00
# 33   5515167              HORLICK, SUSAN       222     20670.00      93.11
# 34   5601495            HUDSON, BRUCE S.        11     17000.00    1545.45
# 35   4684620           GROSSBLATT, DAVID         6     16033.00    2672.17
# 36   3850042                FORDE, JAMES         4     13500.00    3375.00
# 37   5486301          HONARKAR, MOHAMMAD        43     11950.00     277.91
# 38  11024692             SHOCH, JOHN PHD         2     11000.00    5500.00
# 39   2576925           CUELLAR, CLIFFORD        54     10584.00     196.00
# 40   9688035                 PROOPS, JAY         2     10250.00    5125.00
# 41    678448                BASSI, STEVE         1     10233.00   10233.00
# 42   6872845             LAWRENCE, FRANK        11     10165.00     924.09
# 43  11823232              SWINDELL, DAVE         2     10000.00    5000.00
# 44   5902719               JHONG, EUGENE         8      8802.00    1100.25
# 45   3997846          FRIEDMAN, RANDOLPH         2      7700.00    3850.00
# 46    877907                  BERG, FRED        17      6005.00     353.24
# 47   9625220                 POWERS, ANN        13      5110.00     393.08
# 48   8496236           MOUNT, PHYLLIS F.         6      5071.00     845.17
# 49   4828088                HALL, CLAIRE         2      5000.00    2500.00
#
#    min_amount max_amount                                       elect_cycles
# 0    -2700.00  100000.00   [2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020]
# 1    -2800.00   73175.00                                 [2016, 2018, 2020]
# 2    -2700.00   50000.00                           [2014, 2016, 2018, 2020]
# 3    -1700.00   33400.00                     [2012, 2014, 2016, 2018, 2020]
# 4    -2700.00   33900.00                                       [2016, 2018]
# 5    -2500.00   50000.00  [2002, 2004, 2006, 2008, 2010, 2012, 2014, 201...
# 6      250.00   66100.00                                 [2016, 2018, 2020]
# 7    -2800.00  100000.00                           [2014, 2016, 2018, 2020]
# 8       25.00   20000.00                           [2014, 2016, 2018, 2020]
# 9    -2700.00   25000.00                           [2014, 2016, 2018, 2020]
# 10   -2700.00  100000.00                                       [2018, 2020]
# 11   -2800.00   10000.00                     [2004, 2014, 2016, 2018, 2020]
# 12   -2800.00   25000.00                           [2010, 2016, 2018, 2020]
# 13       3.00   10000.00                           [2014, 2016, 2018, 2020]
# 14   -2700.00  102281.00                                       [2018, 2020]
# 15    1000.00    5000.00                           [2014, 2016, 2018, 2020]
# 16     100.00    3000.00               [2010, 2012, 2014, 2016, 2018, 2020]
# 17       5.00    2700.00         [2004, 2006, 2012, 2014, 2016, 2018, 2020]
# 18    1000.00  100000.00                                       [2016, 2018]
# 19     500.00   25000.00                                 [2006, 2014, 2016]
# 20    -500.00    2000.00                           [2014, 2016, 2018, 2020]
# 21   -2600.00    7500.00                           [2014, 2016, 2018, 2020]
# 22     376.00   50000.00                                             [2018]
# 23   -1000.00    2700.00                     [2012, 2014, 2016, 2018, 2020]
# 24    1000.00    5400.00                           [2014, 2016, 2018, 2020]
# 25      15.00    2500.00               [2004, 2006, 2014, 2016, 2018, 2020]
# 26   -2700.00   10239.00                                             [2018]
# 27      25.00    5000.00                           [2014, 2016, 2018, 2020]
# 28     -20.00    5000.00                                 [2016, 2018, 2020]
# 29     100.00    2500.00                           [2014, 2016, 2018, 2020]
# 30   -2744.00   24945.00                                             [2018]
# 31   25000.00   25000.00                                             [2018]
# 32   -2699.00   11189.00                                             [2018]
# 33       1.00     500.00                                 [2016, 2018, 2020]
# 34     300.00    5000.00                                             [2016]
# 35   -2440.00   10115.00                                             [2018]
# 36    2700.00    5400.00                                             [2018]
# 37   -2000.00   10000.00                                       [2016, 2018]
# 38    1000.00   10000.00                                       [2016, 2018]
# 39       1.00    5000.00                                 [2016, 2018, 2020]
# 40     250.00   10000.00                                             [2018]
# 41   10233.00   10233.00                                             [2018]
# 42       5.00    5000.00                                       [2016, 2020]
# 43    5000.00    5000.00                                             [2018]
# 44   -2700.00    8302.00                                       [2018, 2020]
# 45    2700.00    5000.00                                       [2018, 2020]
# 46      25.00    2510.00                                       [2016, 2018]
# 47       5.00    1000.00                                       [2016, 2018]
# 48       5.00    2500.00                                       [2018, 2020]
# 49    2500.00    2500.00                                             [2018]

# %%
# %%sql
# select d.id as donor_id,
#        d.name as donor_name,
#        cx.elect_cycle,
#        count(*) cycle_contribs,
#        sum(cx.transaction_amt) cycle_amount,
#        round(avg(cx.transaction_amt), 2) avg_amount,
#        min(cx.transaction_amt) min_amount,
#        max(cx.transaction_amt) max_amount
#   from ctx_contrib cx
#   join donor_indiv d on d.id = cx.donor_indiv_id
#  group by 1, 2, 3
#  order by 5 desc
#  limit 50
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 50 rows affected.
#     donor_id                  donor_name  elect_cycle  cycle_contribs  \
# 0   10979072              SHENKER, SCOTT         2018             175
# 1    6169689            KARPLUS, BARBARA         2018             261
# 2     779629           BEEUWKES, REINIER         2018             206
# 3    1083690                 BLUE, ALLEN         2016              62
# 4   11902785                TAYLOR, DALE         2018              38
# 5      28429            ABRAMSON, RONALD         2018             176
# 6    6169689            KARPLUS, BARBARA         2016              35
# 7     779629           BEEUWKES, REINIER         2016             141
# 8    7863787                MCEVOY, NION         2018             325
# 9    9188602                  PARK, TODD         2018              22
# 10     28429            ABRAMSON, RONALD         2016              75
# 11   4336953          GIRARDI, THOMAS V.         2014               6
# 12   1083690                 BLUE, ALLEN         2018              19
# 13   1661575                BYERS, BROOK         2018              37
# 14  10979072              SHENKER, SCOTT         2016              42
# 15    779629           BEEUWKES, REINIER         2014              52
# 16   6169689            KARPLUS, BARBARA         2020              44
# 17  10325529             ROSZAK, MATTHEW         2018               5
# 18   9683572  PROCKOP, DARWIN J. MD, PHD         2018               2
# 19  10979072              SHENKER, SCOTT         2014              23
# 20  11659801      STOREY, BAYARD T PH.D.         2016              11
# 21   6433238                  KIRK, CLAY         2018              44
# 22    779629           BEEUWKES, REINIER         2020              30
# 23     28429            ABRAMSON, RONALD         2014              25
# 24   4336953          GIRARDI, THOMAS V.         2018              11
# 25   7863787                MCEVOY, NION         2016             145
# 26   8848719                NORTON, JACK         2018             122
# 27   6822374               LARSEN, CHRIS         2018              13
# 28   8656333               NASH, RICHARD         2018               5
# 29   4435025               GOLLON, PETER         2018             101
# 30   8793106             NIELSEN, SHEILA         2018             320
# 31   4745356              GURAL, JEFFREY         2018              16
# 32   6110433              KAHN, RONALD N         2018              18
# 33     28429            ABRAMSON, RONALD         2020              18
# 34   6433238                  KIRK, CLAY         2016              25
# 35   7863787                MCEVOY, NION         2020               1
# 36   5870457         JENCKS, CHRISTOPHER         2018             203
# 37   6433238                  KIRK, CLAY         2014              19
# 38   4745356              GURAL, JEFFREY         2016              14

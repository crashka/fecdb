# %% [markdown]
# # Query by Donor #
#
# ## Overview ##
#
# Explore the FEC data by specifying SQL predicates that identify **Donors**, which are sets of Individual (`indiv` table) records deemed (e.g. conjectured or asserted) to represent the same real-world person.  The advantage of using Donor (over Individual) is that it is possible to distinguish between the contribution of distinct people identities within a result set (to the degree that the Donor mappings are accurate).
#
# This approach will create the following query contexts:
#
# * `ctx_donor`
# * `ctx_indiv`
# * `ctx_contrib`

# %% [markdown]
# ## Notebook Setup ##
#
# * Configure database connect information and options
# * Clear potentially interfering context (PostgreSQL doesn't let you replace a view definition with conflicting column names)
# * Set styling for notebook

# %%
sqlconnect = "postgresql+psycopg2://crash@localhost/fecdb"

# %load_ext sql
# %config SqlMagic.autopandas=True
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'
# %sql $sqlconnect
# Out:
# 'Connected: crash@fecdb'

# %%
# %sql drop view if exists ctx_contrib cascade
# %sql drop view if exists ctx_indiv cascade
# %sql drop view if exists ctx_donor cascade
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%html
# <style>
#   tr, th, td {
#     text-align: left !important;
#   }
# </style>
# Out:
# <style>
#   tr, th, td {
#     text-align: left !important;
#   }
# </style>

# %% [markdown]
# ## Create Donor Identities ##
#
# Since the single-donor case is pretty straightforward, let's go with a multi-donor example here.  We'll create Donor identities for each of the people we have identified in the household examined in `el_queries1.sql` and `el_queries3.sql`.
#
# First, we identity the primary donor in the household.

# %%
# %%sql result <<
# with indiv_set as (
#     select i.*
#       from indiv i
#      where i.name like 'SANDELL, SCOTT%'
#        and i.zip_code ~ '9402[58]'
#        and i.name !~ 'MRS\.'
# )
# select set_donor_indiv('indiv', array_agg(id)) as donor_indiv_id
#   from indiv_set
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 1 rows affected.
# Returning data to local variable result

# %%
donor_indiv_id1 = int(result.loc[0][0])
# Out:
# 10527429

# %% [markdown]
# Next, we identify the other donor (or, remaining donors) in the household, by exclusion

# %%
# %%sql result <<
# with indiv_set as (
#     select i.*
#       from indiv i
#      where i.name like 'SANDELL, %'
#        and i.zip_code ~ '9402[58]'
#        and coalesce(i.donor_indiv_id, 0) != :donor_indiv_id1
# )
# select set_donor_indiv('indiv', array_agg(id)) as donor_indiv_id
#   from indiv_set
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 1 rows affected.
# Returning data to local variable result

# %%
donor_indiv_id2 = int(result.loc[0][0])
# Out:
# 10527363

# %% [markdown]
# ## Create Context Views ##
#
# ### Create `ctx_donor` ###
#
# Now we set the query context to be the combinatin of the two Donor identities just created (identified by `donor_indiv_id`)

# %%
# %%sql
# create or replace view ctx_donor as
# select d.*
#   from donor_indiv d
#  where d.id in (:donor_indiv_id1, :donor_indiv_id2)
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Let's take a quick look at the context before proceeding.  Note: even though these records are coming from the `indiv` table, we really consider them to be coming from the `donor_indiv` view, thus in the **Donor** domain (and not the **Individual** domain).

# %%
# %%sql
# select id,
#        name,
#        city,
#        state,
#        zip_code,
#        elect_cycles
#   from ctx_donor
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 2 rows affected.
#          id               name        city state zip_code  \
# 0  10527363  SANDELL, JENNIFER  MENLO PARK    CA    94025
# 1  10527429     SANDELL, SCOTT  MENLO PARK    CA    94025
#
#                      elect_cycles
# 0        [2004, 2006, 2008, 2010]
# 1  [2000, 2008, 2010, 2012, 2016]

# %% [markdown]
# ### Create `ctx_indiv` ###

# %%
# %%sql
# create or replace view ctx_indiv as
# select i.*
#   from ctx_donor dx
#   join indiv i on i.donor_indiv_id = dx.id
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# And visually inspect...

# %%
# %%sql
# select id,
#        name,
#        city,
#        state,
#        zip_code,
#        elect_cycles,
#        donor_indiv_id
#   from ctx_indiv
#  order by donor_indiv_id
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 27 rows affected.
#           id                     name            city state   zip_code  \
# 0   10527365        SANDELL, JENNIFER  PORTOLA VALLEY    CA      94028
# 1   10527366        SANDELL, JENNIFER  PORTOLA VALLEY    CA  940287608
# 2   10527364        SANDELL, JENNIFER      MENLO PARK    CA     940250
# 3   10527370   SANDELL, JENNIFER AYER      MENLO PARK    CA      94025
# 4   10527371    SANDELL, JENNIFER MS.      MENLO PARK    CA      94025
# 5   10527368      SANDELL, JENNIFER A      MENLO PARK    CA      94025
# 6   10527363        SANDELL, JENNIFER      MENLO PARK    CA      94025
# 7   10527369  SANDELL, JENNIFER A MS.      MENLO PARK    CA      94025
# 8   10527447      SANDELL, SCOTT MRS.      MENLO PARK    CA      94025
# 9   10527442       SANDELL, SCOTT MR.      MENLO PARK    CA      94025
# 10  10527439        SANDELL, SCOTT D.      MENLO PARK    CA  940257022
# 11  10527446       SANDELL, SCOTT MR.  PORTOLA VALLEY    CA  940287608
# 12  10527440        SANDELL, SCOTT D.  PORTOLA VALLEY    CA      94028
# 13  10527436         SANDELL, SCOTT D  PORTOLA VALLEY    CA      94028
# 14  10527432           SANDELL, SCOTT  PORTOLA VALLEY    CA  940287608
# 15  10527443       SANDELL, SCOTT MR.      MENLO PARK    CA  940256940
# 16  10527444       SANDELL, SCOTT MR.      MENLO PARK    CA  940257022
# 17  10527441    SANDELL, SCOTT D. MR.      MENLO PARK    CA      94025
# 18  10527434         SANDELL, SCOTT D      MENLO PARK    CA  940256112
# 19  10527431           SANDELL, SCOTT  PORTOLA VALLEY    CA      94028
# 20  10527438        SANDELL, SCOTT D.      MENLO PARK    CA      94025
# 21  10527445       SANDELL, SCOTT MR.  PORTOLA VALLEY    CA      94028
# 22  10527437         SANDELL, SCOTT D  PORTOLA VALLEY    CA  940287608
# 23  10527435         SANDELL, SCOTT D      MENLO PARK    CA  940257022
# 24  10527429           SANDELL, SCOTT      MENLO PARK    CA      94025
# 25  10527430           SANDELL, SCOTT      MENLO PARK    CA  940257022
# 26  10527433         SANDELL, SCOTT D      MENLO PARK    CA      94025
#
#                       elect_cycles  donor_indiv_id
# 0                           [2018]        10527363
# 1               [2016, 2018, 2020]        10527363
# 2                           [2004]        10527363
# 3                     [2004, 2010]        10527363
# 4                           [2004]        10527363
# 5                     [2006, 2008]        10527363
# 6         [2004, 2006, 2008, 2010]        10527363
# 7                           [2004]        10527363
# 8                           [2004]        10527363
# 9         [2000, 2002, 2004, 2006]        10527429
# 10                          [2018]        10527429
# 11                          [2018]        10527429
# 12                          [2016]        10527429
# 13                          [2012]        10527429
# 14                          [2016]        10527429
# 15                    [2004, 2006]        10527429
# 16                    [2018, 2020]        10527429
# 17        [2000, 2008, 2010, 2012]        10527429
# 18                          [2014]        10527429
# 19                    [2010, 2016]        10527429
# 20                          [2010]        10527429
# 21                          [2018]        10527429
# 22                          [2016]        10527429
# 23                          [2016]        10527429
# 24  [2000, 2008, 2010, 2012, 2016]        10527429
# 25              [2016, 2018, 2020]        10527429
# 26        [2004, 2006, 2008, 2010]        10527429

# %% [markdown]
# ### Create `ctx_contrib` ###
#
# Note that we are adding `donor_indiv_id` to this view (on top of the `indiv_contrib` columns) so that queries using this context view are able to join to and/or group by the underlying Donor record (and not just the Individual associated with the contribution record), as shown in the second validation query below.

# %%
# %%sql
# create or replace view ctx_contrib as
# select ic.*,
#        ix.donor_indiv_id
#   from ctx_indiv ix
#   join indiv_contrib ic on ic.indiv_id = ix.id
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# Done.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
# select count(*)             as contribs,
#        sum(transaction_amt) as total_amt,
#        array_agg(distinct elect_cycle) as elect_cycles
#   from ctx_contrib
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 1 rows affected.
#    contribs  total_amt                                       elect_cycles
# 0       101  264450.00  [2000, 2002, 2004, 2006, 2008, 2010, 2012, 201...

# %%
# %%sql
# select d.id                 as donor_id,
#        d.name               as donor_name,
#        count(*)             as contribs,
#        sum(transaction_amt) as total_amt,
#        array_agg(distinct elect_cycle) as elect_cycles
#   from ctx_contrib cx
#   join donor_indiv d on d.id = cx.donor_indiv_id
#  group by 1, 2
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 2 rows affected.
#    donor_id         donor_name  contribs  total_amt  \
# 0  10527363  SANDELL, JENNIFER        28   37200.00
# 1  10527429     SANDELL, SCOTT        73  227250.00
#
#                                         elect_cycles
# 0         [2004, 2006, 2008, 2010, 2016, 2018, 2020]
# 1  [2000, 2002, 2004, 2006, 2008, 2010, 2012, 201...

# %% [markdown]
# ## Query Based on Context ##
#
# ### Query using `ctx_donor` ###

# %%
# %%sql
# select ic.elect_cycle,
#        count(*) cycle_contribs,
#        sum(ic.transaction_amt) cycle_amount,
#        round(avg(ic.transaction_amt), 2) avg_amount,
#        min(ic.transaction_amt) min_amount,
#        max(ic.transaction_amt) max_amount
#   from ctx_donor dx
#   join indiv i on i.donor_indiv_id = dx.id
#   join indiv_contrib ic on ic.indiv_id = i.id
#  group by 1
#  order by 1
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 11 rows affected.
#     elect_cycle  cycle_contribs cycle_amount avg_amount min_amount max_amount
# 0          2000               4      2000.00     500.00     250.00    1000.00
# 1          2002               3      5800.00    1933.33    1400.00    2500.00
# 2          2004              15     17400.00    1160.00     250.00    2500.00
# 3          2006               6      9350.00    1558.33    1000.00    2500.00
# 4          2008              17     17200.00    1011.76   -2300.00    2300.00
# 5          2010              11     20750.00    1886.36    1000.00    5000.00
# 6          2012               4      3650.00     912.50     500.00    1175.00
# 7          2014               1      2500.00    2500.00    2500.00    2500.00
# 8          2016              24     88200.00    3675.00   -2500.00   20000.00
# 9          2018              12     86000.00    7166.67    2500.00   20000.00
# 10         2020               4     11600.00    2900.00    1000.00    5000.00

# %% [markdown]
# ### Query using `ctx_indiv` ###

# %%
# %%sql
# select ic.elect_cycle,
#        count(*) cycle_contribs,
#        sum(ic.transaction_amt) cycle_amount,
#        round(avg(ic.transaction_amt), 2) avg_amount,
#        min(ic.transaction_amt) min_amount,
#        max(ic.transaction_amt) max_amount
#   from ctx_indiv ix
#   join indiv_contrib ic on ic.indiv_id = ix.id
#  group by 1
#  order by 1
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 11 rows affected.
#     elect_cycle  cycle_contribs cycle_amount avg_amount min_amount max_amount
# 0          2000               4      2000.00     500.00     250.00    1000.00
# 1          2002               3      5800.00    1933.33    1400.00    2500.00
# 2          2004              15     17400.00    1160.00     250.00    2500.00
# 3          2006               6      9350.00    1558.33    1000.00    2500.00
# 4          2008              17     17200.00    1011.76   -2300.00    2300.00
# 5          2010              11     20750.00    1886.36    1000.00    5000.00
# 6          2012               4      3650.00     912.50     500.00    1175.00
# 7          2014               1      2500.00    2500.00    2500.00    2500.00
# 8          2016              24     88200.00    3675.00   -2500.00   20000.00
# 9          2018              12     86000.00    7166.67    2500.00   20000.00
# 10         2020               4     11600.00    2900.00    1000.00    5000.00

# %% [markdown]
# ### Query using `ctx_contrib` ###

# %%
# %%sql
# select cx.elect_cycle,
#        count(*) cycle_contribs,
#        sum(cx.transaction_amt) cycle_amount,
#        round(avg(cx.transaction_amt), 2) avg_amount,
#        min(cx.transaction_amt) min_amount,
#        max(cx.transaction_amt) max_amount
#   from ctx_contrib cx
#  group by 1
#  order by 1
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 11 rows affected.
#     elect_cycle  cycle_contribs cycle_amount avg_amount min_amount max_amount
# 0          2000               4      2000.00     500.00     250.00    1000.00
# 1          2002               3      5800.00    1933.33    1400.00    2500.00
# 2          2004              15     17400.00    1160.00     250.00    2500.00
# 3          2006               6      9350.00    1558.33    1000.00    2500.00
# 4          2008              17     17200.00    1011.76   -2300.00    2300.00
# 5          2010              11     20750.00    1886.36    1000.00    5000.00
# 6          2012               4      3650.00     912.50     500.00    1175.00
# 7          2014               1      2500.00    2500.00    2500.00    2500.00
# 8          2016              24     88200.00    3675.00   -2500.00   20000.00
# 9          2018              12     86000.00    7166.67    2500.00   20000.00
# 10         2020               4     11600.00    2900.00    1000.00    5000.00

# %%
# %%sql
# select d.id as donor_id,
#        d.name as donor_name,
#        cx.elect_cycle,
#        count(*) cycle_contribs,
#        sum(cx.transaction_amt) cycle_amount,
#        round(avg(cx.transaction_amt), 2) avg_amount,
#        min(cx.transaction_amt) min_amount,
#        max(cx.transaction_amt) max_amount
#   from ctx_contrib cx
#   join donor_indiv d on d.id = cx.donor_indiv_id
#  group by 1, 2, 3
#  order by 5 desc
# Out:
#  * postgresql+psycopg2://crash@localhost/fecdb
# 18 rows affected.
#     donor_id         donor_name  elect_cycle  cycle_contribs cycle_amount  \
# 0   10527429     SANDELL, SCOTT         2016              21     83500.00
# 1   10527429     SANDELL, SCOTT         2018              10     80600.00
# 2   10527429     SANDELL, SCOTT         2010               9     15950.00
# 3   10527429     SANDELL, SCOTT         2008              10     10650.00
# 4   10527429     SANDELL, SCOTT         2020               3     10600.00
# 5   10527363  SANDELL, JENNIFER         2004              10     10250.00
# 6   10527429     SANDELL, SCOTT         2004               5      7150.00
# 7   10527363  SANDELL, JENNIFER         2008               7      6550.00
# 8   10527429     SANDELL, SCOTT         2002               3      5800.00
# 9   10527363  SANDELL, JENNIFER         2018               2      5400.00
# 10  10527429     SANDELL, SCOTT         2006               3      4850.00
# 11  10527363  SANDELL, JENNIFER         2010               2      4800.00
# 12  10527363  SANDELL, JENNIFER         2016               3      4700.00
# 13  10527363  SANDELL, JENNIFER         2006               3      4500.00
# 14  10527429     SANDELL, SCOTT         2012               4      3650.00
# 15  10527429     SANDELL, SCOTT         2014               1      2500.00
# 16  10527429     SANDELL, SCOTT         2000               4      2000.00
# 17  10527363  SANDELL, JENNIFER         2020               1      1000.00
#
#    avg_amount min_amount max_amount
# 0     3976.19   -2500.00   20000.00
# 1     8060.00    2500.00   20000.00
# 2     1772.22    1000.00    5000.00
# 3     1065.00   -2300.00    2300.00
# 4     3533.33    2800.00    5000.00
# 5     1025.00     250.00    2500.00
# 6     1430.00     500.00    2000.00
# 7      935.71     250.00    2300.00
# 8     1933.33    1400.00    2500.00
# 9     2700.00    2700.00    2700.00
# 10    1616.67    1100.00    2500.00
# 11    2400.00    2400.00    2400.00
# 12    1566.67    1000.00    2700.00
# 13    1500.00    1000.00    2500.00
# 14     912.50     500.00    1175.00
# 15    2500.00    2500.00    2500.00
# 16     500.00     250.00    1000.00
# 17    1000.00    1000.00    1000.00
